# %% [markdown]
# To install the widget for jupyter notebook or jupyterlab, please read instructions of "Local Dev Installation" in
# https://github.com/jupyter-widgets/widget-cookiecutter

# %%
import jupyter_d3_widget
import pandas as pd

# %%
''' When the widget project is genereated automatically, the class name in the widget is HelloWorld()'''
# mywidget = jupyter_d3_widget.HelloWorld()
# Out:
# ' When the widget project is genereated automatically, the class name in the widget is HelloWorld()'

# %%
''' We change the class name to Scatterplot afterwards'''
mywidget = jupyter_d3_widget.Scatterplot()

# %%
url = 'https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/2_TwoNum.csv'
df = pd.read_csv(url,sep=",")
df.head()
# Out:
#    GrLivArea  SalePrice
# 0       1710     208500
# 1       1262     181500
# 2       1786     223500
# 3       1717     140000
# 4       2198     250000

# %%
value = df.to_dict('records')

# %%
value
# Out:
# [{'GrLivArea': 1710, 'SalePrice': 208500},
#  {'GrLivArea': 1262, 'SalePrice': 181500},
#  {'GrLivArea': 1786, 'SalePrice': 223500},
#  {'GrLivArea': 1717, 'SalePrice': 140000},
#  {'GrLivArea': 2198, 'SalePrice': 250000},
#  {'GrLivArea': 1362, 'SalePrice': 143000},
#  {'GrLivArea': 1694, 'SalePrice': 307000},
#  {'GrLivArea': 2090, 'SalePrice': 200000},
#  {'GrLivArea': 1774, 'SalePrice': 129900},
#  {'GrLivArea': 1077, 'SalePrice': 118000},
#  {'GrLivArea': 1040, 'SalePrice': 129500},
#  {'GrLivArea': 2324, 'SalePrice': 345000},
#  {'GrLivArea': 912, 'SalePrice': 144000},
#  {'GrLivArea': 1494, 'SalePrice': 279500},
#  {'GrLivArea': 1253, 'SalePrice': 157000},
#  {'GrLivArea': 854, 'SalePrice': 132000},
#  {'GrLivArea': 1004, 'SalePrice': 149000},
#  {'GrLivArea': 1296, 'SalePrice': 90000},
#  {'GrLivArea': 1114, 'SalePrice': 159000},
#  {'GrLivArea': 1339, 'SalePrice': 139000},
#  {'GrLivArea': 2376, 'SalePrice': 325300},
#  {'GrLivArea': 1108, 'SalePrice': 139400},
# ...

# %%
mywidget.initialize(value)

# %%
mywidget
# Out:
# Scatterplot(value=[{'GrLivArea': 1710, 'SalePrice': 208500}, {'GrLivArea': 1262, 'SalePrice': 181500}, {'GrLiv…
